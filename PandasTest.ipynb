# %%
import pandas as pd
import numpy as np

# %%
df_memeber = pd.read_excel('./memberstatus.xlsx')
df_memeber.head()
# Out:
#     UserID               Name userName    ChatID forbidden  forbidden2
# 0  1235468                NaN     mkmk     mksjd       sex         NaN
# 1   123265                NaN     mjmj      lklk     doggy         NaN
# 2   365236                NaN      man     shome     hibye         NaN
# 3    99980  ['ali', 'hassan']      NaN  sexylady       NaN         NaN
# 4   365236                NaN      man     shome     hibye         NaN

# %%
arr = {'user_id': 123265, 'user_name': 'mjmj', 'chat_id':'lklk', 'forbiden':'doggy'}

# %%
df_memeber.columns
# Out:
# Index(['UserID', 'Name', 'userName', 'ChatID', 'forbidden', 'forbidden2'], dtype='object')

# %%
df_memeber.columns[1]
# Out:
# 'Name'

# %%
df_memeber.columns = ["UserID","Name", "userName", "ChatID", "forbidden", "forbidden2"]
df_memeber.columns
# Out:
# Index(['UserID', 'Name', 'userName', 'ChatID', 'forbidden', 'forbidden2'], dtype='object')

# %%
df_memeber.head()
# Out:
#     UserID               Name userName    ChatID forbidden  forbidden2
# 0  1235468                NaN     mkmk     mksjd       sex         NaN
# 1   123265                NaN     mjmj      lklk     doggy         NaN
# 2   365236                NaN      man     shome     hibye         NaN
# 3    99980  ['ali', 'hassan']      NaN  sexylady       NaN         NaN
# 4   365236                NaN      man     shome     hibye         NaN

# %%
df_memeber.rename(columns={"userID":"UserID","chatID": "ChatID"})
df_memeber.head()
# Out:
#     UserID               Name userName    ChatID forbidden  forbidden2
# 0  1235468                NaN     mkmk     mksjd       sex         NaN
# 1   123265                NaN     mjmj      lklk     doggy         NaN
# 2   365236                NaN      man     shome     hibye         NaN
# 3    99980  ['ali', 'hassan']      NaN  sexylady       NaN         NaN
# 4   365236                NaN      man     shome     hibye         NaN

# %%
df_memeber.rename(columns={"userID":"UserID","chatID": "ChatID"}, inplace=True)
df_memeber.head()
# Out:
#     UserID               Name userName    ChatID forbidden  forbidden2
# 0  1235468                NaN     mkmk     mksjd       sex         NaN
# 1   123265                NaN     mjmj      lklk     doggy         NaN
# 2   365236                NaN      man     shome     hibye         NaN
# 3    99980  ['ali', 'hassan']      NaN  sexylady       NaN         NaN
# 4   365236                NaN      man     shome     hibye         NaN

# %%
arr = {'UserID': 123265, 'userName': 'mjmj', 'ChatID':'lklk', 'forbidden':'doggy'}

df_memeber.loc[1] = arr

# %%
df_memeber.head()
# Out:
#     UserID               Name userName    ChatID forbidden  forbidden2
# 0  1235468                NaN     mkmk     mksjd       sex         NaN
# 1   123265                NaN     mjmj      lklk     doggy         NaN
# 2   365236                NaN      man     shome     hibye         NaN
# 3    99980  ['ali', 'hassan']      NaN  sexylady       NaN         NaN
# 4   365236                NaN      man     shome     hibye         NaN

# %%
number = len(df_memeber.index)
print(number)
arr = {'UserID': 1232312125, 'userName': 'man', 'ChatID':'to', 'forbidden':'hihi'}
df_memeber.loc[len(df_memeber)] = arr
df_memeber.head()
# Out:
# 6
#     UserID               Name userName    ChatID forbidden  forbidden2
# 0  1235468                NaN     mkmk     mksjd       sex         NaN
# 1   123265                NaN     mjmj      lklk     doggy         NaN
# 2   365236                NaN      man     shome     hibye         NaN
# 3    99980  ['ali', 'hassan']      NaN  sexylady       NaN         NaN
# 4   365236                NaN      man     shome     hibye         NaN

# %%
df_memeber.loc[len(df_memeber)-1, ['UserID', 'ChatID']] = [365236, "shome"]
df_memeber.head()
# Out:
#     UserID               Name userName    ChatID forbidden  forbidden2
# 0  1235468                NaN     mkmk     mksjd       sex         NaN
# 1   123265                NaN     mjmj      lklk     doggy         NaN
# 2   365236                NaN      man     shome     hibye         NaN
# 3    99980  ['ali', 'hassan']      NaN  sexylady       NaN         NaN
# 4   365236                NaN      man     shome     hibye         NaN

# %%
df_memeber.at[2, "UserID"]
# Out:
# 365236

# %%
df_memeber.loc[len(df_memeber)-1, 'forbidden'] = 'hibye'
df_memeber.head()
# Out:
#     UserID               Name userName    ChatID forbidden  forbidden2
# 0  1235468                NaN     mkmk     mksjd       sex         NaN
# 1   123265                NaN     mjmj      lklk     doggy         NaN
# 2   365236                NaN      man     shome     hibye         NaN
# 3    99980  ['ali', 'hassan']      NaN  sexylady       NaN         NaN
# 4   365236                NaN      man     shome     hibye         NaN

# %%
df_memeber.head()
# Out:
#     UserID               Name userName    ChatID forbidden  forbidden2
# 0  1235468                NaN     mkmk     mksjd       sex         NaN
# 1   123265                NaN     mjmj      lklk     doggy         NaN
# 2   365236                NaN      man     shome     hibye         NaN
# 3    99980  ['ali', 'hassan']      NaN  sexylady       NaN         NaN
# 4   365236                NaN      man     shome     hibye         NaN

# %%
filt = (df_memeber["ChatID"] == "to")
df_memeber[filt]["UserID"] = 99985
df_memeber
# Out:
#     UserID               Name userName    ChatID forbidden  forbidden2
# 0  1235468                NaN     mkmk     mksjd       sex         NaN
# 1   123265                NaN     mjmj      lklk     doggy         NaN
# 2   365236                NaN      man     shome     hibye         NaN
# 3    99980  ['ali', 'hassan']      NaN  sexylady       NaN         NaN
# 4   365236                NaN      man     shome     hibye         NaN
# 5    99980                NaN      NaN  sexylady       NaN         NaN
# 6   365236                NaN      man     shome     hibye         NaN

# %%
filt = (df_memeber["ChatID"] == "to")
df_memeber.loc[filt,"UserID"] = 99985
df_memeber
# Out:
#     UserID               Name userName    ChatID forbidden  forbidden2
# 0  1235468                NaN     mkmk     mksjd       sex         NaN
# 1   123265                NaN     mjmj      lklk     doggy         NaN
# 2   365236                NaN      man     shome     hibye         NaN
# 3    99980  ['ali', 'hassan']      NaN  sexylady       NaN         NaN
# 4   365236                NaN      man     shome     hibye         NaN
# 5    99980                NaN      NaN  sexylady       NaN         NaN
# 6   365236                NaN      man     shome     hibye         NaN

# %%
df_memeber["userName"].str.upper()
df_memeber
# Out:
#     UserID               Name userName    ChatID forbidden  forbidden2
# 0  1235468                NaN     mkmk     mksjd       sex         NaN
# 1   123265                NaN     mjmj      lklk     doggy         NaN
# 2   365236                NaN      man     shome     hibye         NaN
# 3    99980  ['ali', 'hassan']      NaN  sexylady       NaN         NaN
# 4   365236                NaN      man     shome     hibye         NaN
# 5    99980                NaN      NaN  sexylady       NaN         NaN
# 6   365236                NaN      man     shome     hibye         NaN

# %%
df_memeber["userName"] = df_memeber["userName"].str.upper()
df_memeber
# Out:
#     UserID               Name userName    ChatID forbidden  forbidden2
# 0  1235468                NaN     MKMK     mksjd       sex         NaN
# 1   123265                NaN     MJMJ      lklk     doggy         NaN
# 2   365236                NaN      MAN     shome     hibye         NaN
# 3    99980  ['ali', 'hassan']      NaN  sexylady       NaN         NaN
# 4   365236                NaN      MAN     shome     hibye         NaN
# 5    99980                NaN      NaN  sexylady       NaN         NaN
# 6   365236                NaN      MAN     shome     hibye         NaN

# %%
df_memeber["userName"] = df_memeber["userName"].str.lower()
df_memeber
# Out:
#     UserID               Name userName    ChatID forbidden  forbidden2
# 0  1235468                NaN     mkmk     mksjd       sex         NaN
# 1   123265                NaN     mjmj      lklk     doggy         NaN
# 2   365236                NaN      man     shome     hibye         NaN
# 3    99980  ['ali', 'hassan']      NaN  sexylady       NaN         NaN
# 4   365236                NaN      man     shome     hibye         NaN
# 5    99980                NaN      NaN  sexylady       NaN         NaN
# 6   365236                NaN      man     shome     hibye         NaN

# %%
df_memeber["ChatID"].apply(len)
# Out:
# 0    5
# 1    4
# 2    5
# 3    8
# 4    5
# 5    8
# 6    5
# Name: ChatID, dtype: int64

# %%
def uppermake(text):
    return text.upper()

# %%
df_memeber["ChatID"].apply(uppermake)
# Out:
# 0       MKSJD
# 1        LKLK
# 2       SHOME
# 3    SEXYLADY
# 4       SHOME
# 5    SEXYLADY
# 6       SHOME
# Name: ChatID, dtype: object

# %%
df_memeber.loc[len(df_memeber),"UserID"] = 99980

# %%
df_memeber
# Out:
#       UserID               Name userName    ChatID forbidden  forbidden2
# 0  1235468.0                NaN     mkmk     mksjd       sex         NaN
# 1   123265.0                NaN     mjmj      lklk     doggy         NaN
# 2   365236.0                NaN      man     shome     hibye         NaN
# 3    99980.0  ['ali', 'hassan']      NaN  sexylady       NaN         NaN
# 4   365236.0                NaN      man     shome     hibye         NaN
# 5    99980.0                NaN      NaN  sexylady       NaN         NaN
# 6   365236.0                NaN      man     shome     hibye         NaN
# 7    99980.0                NaN      NaN       NaN       NaN         NaN

# %%
filt = (df_memeber["UserID"] == 200)
filt
# Out:
# 0    False
# 1    False
# 2    False
# 3    False
# 4    False
# 5    False
# 6    False
# 7    False
# Name: UserID, dtype: bool

# %%
df_memeber.loc[len(df_memeber)-1,["Name", "userName", "ChatID"]] = [None, None, "sexylady"]
df_memeber
# Out:
#       UserID               Name userName    ChatID forbidden  forbidden2
# 0  1235468.0                NaN     mkmk     mksjd       sex         NaN
# 1   123265.0                NaN     mjmj      lklk     doggy         NaN
# 2   365236.0                NaN      man     shome     hibye         NaN
# 3    99980.0  ['ali', 'hassan']      NaN  sexylady       NaN         NaN
# 4   365236.0                NaN      man     shome     hibye         NaN
# 5    99980.0                NaN      NaN  sexylady       NaN         NaN
# 6   365236.0                NaN      man     shome     hibye         NaN
# 7    99980.0               None     None  sexylady       NaN         NaN

# %%
df_memeber["ChatID"].apply(lambda x : x.lower())
# Out:
# 0       mksjd
# 1        lklk
# 2       shome
# 3    sexylady
# 4       shome
# 5    sexylady
# 6       shome
# 7    sexylady
# Name: ChatID, dtype: object

# %%
df_memeber.at[3, "Name"] = ["ali", "hassan"]
df_memeber
# Out:
#       UserID           Name userName    ChatID forbidden  forbidden2
# 0  1235468.0            NaN     mkmk     mksjd       sex         NaN
# 1   123265.0            NaN     mjmj      lklk     doggy         NaN
# 2   365236.0            NaN      man     shome     hibye         NaN
# 3    99980.0  [ali, hassan]      NaN  sexylady       NaN         NaN
# 4   365236.0            NaN      man     shome     hibye         NaN
# 5    99980.0            NaN      NaN  sexylady       NaN         NaN
# 6   365236.0            NaN      man     shome     hibye         NaN
# 7    99980.0           None     None  sexylady       NaN         NaN

# %%
userid = df_memeber["UserID"]
print((99980.0 in userid))
if 99980.0 in userid:
    print('yes')
else:
    print('no')
# Out:
# False
# no

# %%
def argmax(x):
    i = 0
    while x[i] == False:
        i = i+1

    return i

# %%
filtr = df_memeber["UserID"] == 99980
print(argmax(filtr))
# Out:
# 3

# %%
filtr = max(df_memeber["UserID"] == 99980)
if filtr:
    print(True)
# Out:
# True

# %%
df_memeber
# Out:
#       UserID           Name userName    ChatID forbidden  forbidden2
# 0  1235468.0            NaN     mkmk     mksjd       sex         NaN
# 1   123265.0            NaN     mjmj      lklk     doggy         NaN
# 2   365236.0            NaN      man     shome     hibye         NaN
# 3    99980.0  [ali, hassan]      NaN  sexylady       NaN         NaN
# 4   365236.0            NaN      man     shome     hibye         NaN
# 5    99980.0            NaN      NaN  sexylady       NaN         NaN
# 6   365236.0            NaN      man     shome     hibye         NaN
# 7    99980.0           None     None  sexylady       NaN         NaN

# %%
name = df_memeber.at[2, "Name"]
print(name)
if type(name) != list:
    name = []
    name.append("hi")
else:
    name.append("bye")
df_memeber.at[2, "Name"] = name
# Out:
# ['hi', 'bye', 'bye']

# %%
df_memeber.to_excel('./memberstatus.xlsx', index=False)

# %%
type(name)

# %%
df_memeber

# %%
pd.isna(df_memeber.loc[4, "Name"])

# %%
type(df_memeber.loc[3, "Name"])

# %%
import torch

# %%
torch.cuda.is_available()
# Out:
# True

# %%
torch.cuda.device_count()
# Out:
# 1

# %%
r = "hello"
s = ","
t = "guys"
rst = r+s+t
rst
# Out:
# 'hello,guys'
